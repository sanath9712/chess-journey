# %%
import pandas as pd
import os

# Directory path for CSV files
csv_data_directory = '../csvdata'  # Adjust the path relative to the src directory

# List to hold DataFrames
dataframes = []

# Iterate over each CSV file in the directory
for filename in os.listdir(csv_data_directory):
    if filename.endswith('.csv'):
        file_path = os.path.join(csv_data_directory, filename)
        df = pd.read_csv(file_path)
        dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# Display the first few rows of the combined DataFrame
print(combined_df.head())
# Out:
#                                            url  \
# 0  https://www.chess.com/game/live/84653154525
# 1  https://www.chess.com/game/live/84658472715
# 2  https://www.chess.com/game/live/84668629003
# 3  https://www.chess.com/game/live/84669762751
# 4  https://www.chess.com/game/live/84671027709
#
#                                                  pgn time_control    end_time  \
# 0  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600  1690914807
# 1  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600  1690919838
# 2  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600  1690930597
# 3  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600  1690930956
# 4  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600  1690932541
#
#    rated                                                tcn  \
# 0   True  mC0KdN!TNK90gvZRKHYQHyTCltCIyzWGzq1LtBICft8!tC...
# 1   True  mC0KdN!VNK70K090gv1LCLVLbs8!sH5OHBOzkszJsAJPBH...
# 2   True  owZJfoJBjr5Qcj!Tgv6SvMQzksBsls3VMS1SoX45Xv7ded...
# 3   True  mCZJCJ7Jbs0SsJSJdm8Zgv9zvB5QBLZ7L2!ToE6EmtQKtH...
# 4   True  nD0KgvKDbs2MsCMEvK7FowDwCw5QKQXQmu!TdmZJedTCwC...
#
#                                    uuid  \
# 0  c9c7ca31-3098-11ee-8179-6cfe544c0428
# 1  e195e1f3-30a4-11ee-8179-6cfe544c0428
# 2  90a6f63e-30bc-11ee-8179-6cfe544c0428
# 3  ce1424fa-30be-11ee-8179-6cfe544c0428
# 4  3d2a398a-30c2-11ee-8179-6cfe544c0428
#
#                                        initial_setup  \
# 0  rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w ...
# 1  rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w ...
# 2  rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w ...
# 3  rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w ...
# 4  rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w ...
#
#                                                  fen time_class  ...  \
# 0   r5k1/6pp/2p5/pp1pb3/6b1/5NP1/PPP4P/RNB1K2q w - -      rapid  ...
# 1  2b2r1k/rp1pb1pp/p2n4/8/8/1B3N2/PP1P1PPP/R1B2RK...      rapid  ...
# 2               5B2/3r4/p7/7q/P1P3k1/4Kn2/P7/8 b - -      rapid  ...
# 3  7Q/2p1kpNp/5n2/1B1p4/1b6/7P/PPPP1P2/R1B1K2b b Q -      rapid  ...
# 4    3rk2r/2p2pbp/8/P1p5/2P5/P1K1P3/2B5/R1B3q1 w k -      rapid  ...
#
#   white.username                            white.uuid black.rating  \
# 0        znatahn  0fa74da4-6bbc-11ec-9e8b-1fb7ef683c22          553
# 1    seinseimatt  fc9cea9c-9c2b-11ed-a0f1-97bfe41179db          495
# 2  manmeetbhalla  1ae4e148-d1a7-11ed-9603-47e3036054ed          502
# 3        znatahn  0fa74da4-6bbc-11ec-9e8b-1fb7ef683c22          515
# 4     Netster333  6bae8258-5d5a-11ed-b631-c3de56696952          519
#
#   black.result                                  black.@id black.username  \
# 0          win  https://api.chess.com/pub/player/udmurtio       UDMURTio
# 1    abandoned   https://api.chess.com/pub/player/znatahn        znatahn
# 2          win   https://api.chess.com/pub/player/znatahn        znatahn
# 3     resigned     https://api.chess.com/pub/player/mz69h          Mz69h
# 4          win   https://api.chess.com/pub/player/znatahn        znatahn
#
#                              black.uuid accuracies.white accuracies.black  \
# 0  41ed7922-77ec-11ed-ba25-415ab022285a              NaN              NaN
# 1  0fa74da4-6bbc-11ec-9e8b-1fb7ef683c22              NaN              NaN
# 2  0fa74da4-6bbc-11ec-9e8b-1fb7ef683c22              NaN              NaN
# 3  ae20513a-985a-11ed-a135-1bea1797fd54              NaN              NaN
# 4  0fa74da4-6bbc-11ec-9e8b-1fb7ef683c22            56.97            64.76
#
#   start_time
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 24 columns]

# %%
combined_df.columns
# Out:
# Index(['url', 'pgn', 'time_control', 'end_time', 'rated', 'tcn', 'uuid',
#        'initial_setup', 'fen', 'time_class', 'rules', 'white.rating',
#        'white.result', 'white.@id', 'white.username', 'white.uuid',
#        'black.rating', 'black.result', 'black.@id', 'black.username',
#        'black.uuid', 'accuracies.white', 'accuracies.black', 'start_time'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Filter for games where you played as white
znatahn_as_white = combined_df[combined_df['white.username'] == 'znatahn']

# Analyze the results
results = znatahn_as_white['white.result'].value_counts()

print(results)

plt.figure(figsize=(10, 6))  # Increase figure size
bars = results.plot(kind='bar', width=0.8)  # Adjust bar width if needed
plt.title('Game Outcomes for znatahn as White')
plt.xlabel('Result')
plt.ylabel('Number of Games')
plt.xticks(rotation=45)  # Rotate labels to 45 degrees

# Adding annotations to each bar
for bar in bars.patches:
    bars.annotate(format(bar.get_height(), '.0f'), 
                  (bar.get_x() + bar.get_width() / 2, 
                   bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')

plt.show()
# Out:
# win                   645
# resigned              223
# abandoned             182
# checkmated            138
# timeout                41
# stalemate              23
# repetition             21
# agreed                 20
# insufficient            8
# timevsinsufficient      6
# Name: white.result, dtype: int64
